# %%
import pandas as pd

# %%
df=pd.read_csv("amazon_reviews_small.csv")

# %%
df=head()

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    return text

df['clean_review'] = df['review_text'].apply(clean_text)
df.head()
# Out:
#                                review_text  \
# 0  This product is amazing and very useful
# 1  Worst quality ever totally disappointed
# 2       Average product okay for the price
# 3  Excellent performance and fast delivery
# 4                      Not worth the money
#
#                               clean_review
# 0  this product is amazing and very useful
# 1  worst quality ever totally disappointed
# 2       average product okay for the price
# 3  excellent performance and fast delivery
# 4                      not worth the money

# %%
from textblob import TextBlob

def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity
    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

df['Sentiment'] = df['clean_review'].apply(get_sentiment)
df
# Out:
#                                 review_text  \
# 0   This product is amazing and very useful
# 1   Worst quality ever totally disappointed
# 2        Average product okay for the price
# 3   Excellent performance and fast delivery
# 4                       Not worth the money
# 5             Very happy with this purchase
# 6     Poor build quality and bad experience
# 7            Nice product I really liked it
# 8                 Terrible service very bad
# 9                      Good value for money
# 10   The product works fine nothing special
# 11       Amazing quality highly recommended
# 12           Bad packaging and damaged item
# 13              Satisfied with the purchase
# 14                Waste of money do not buy
#
#                                clean_review Sentiment
# 0   this product is amazing and very useful  Positive
# 1   worst quality ever totally disappointed  Negative
# 2        average product okay for the price  Positive
# 3   excellent performance and fast delivery  Positive
# 4                       not worth the money  Negative
# 5             very happy with this purchase  Positive
# 6     poor build quality and bad experience  Negative
# 7            nice product i really liked it  Positive
# 8                 terrible service very bad  Negative
# 9                      good value for money  Positive
# 10   the product works fine nothing special  Positive
# 11       amazing quality highly recommended  Positive
# 12           bad packaging and damaged item  Negative
# 13              satisfied with the purchase  Positive
# 14                waste of money do not buy  Negative

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive    9
# Negative    6
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['Sentiment'].value_counts().plot(kind='bar')
plt.title("Amazon Review Sentiment Analysis")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.show()
